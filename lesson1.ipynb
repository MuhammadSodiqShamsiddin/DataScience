# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
pd.read_excel('uzbekistan.xlsx', index_col = 0, names = ['Hudud', 'Maydon', 'Aholi'])
# Out:
#                                Maydon    Aholi
# Hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv('automobile_data.csv', sep = ',', index_col = 'index', nrows = 15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df = pd.read_excel('uzbekistan.xlsx', index_col = 0, names = ['Hudud', 'Maydon', 'Aholi'])
df
# Out:
#                                Maydon    Aholi
# Hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df.to_csv('newuzb')

# %%
obj = df.Maydon
obj
# Out:
# Hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: Maydon, dtype: int64

# %%
obj.to_csv('uzmaydon.csv')

# %%
pd.read_csv('uzmaydon.csv', index_col = 0)
# Out:
#                                Maydon
# Hudud
# Andijon viloyati                 4200
# Buxoro viloyati                 39400
# Fargʻona viloyati                6800
# Jizzax viloyati                 20500
# Xorazm viloyati                  6300
# Namangan viloyati                7900
# Navoiy viloyati                110800
# Qashqadaryo viloyati            28400
# Qoraqalpogʻiston Respublikasi  160000
# Samarqand viloyati              16400
# Sirdaryo viloyati                5100
# Surxondaryo viloyati            20800
# Toshkent viloyati               15300

# %%
df4 = pd.read_csv('uzmaydon.csv', index_col = 0,sep = ',')
series1 = df4.squeeze()
print(series1)
#Katta Rahmat Ishladi
# Out:
# Hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: Maydon, dtype: int64

# %%
import pandas as pd
data = {'A': [1, 2, 3]}
df = pd.DataFrame(data)
series = df.squeeze()

print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
dfu = pd.read_excel("ulamo.xlsx", index = )
# Out:
# C:\Users\QuadroMi\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dfu
# Out:
#      Muso Al-Xorazmiy   783-850                    Xorazm        -
# 0  Ahmad Al-Farg'oniy   797-865             Farg'ona Quva        -
# 1    Abu Nasr Forobiy   873-950  Aris suvi+Sirdaryo Forob        -
# 2    Abu Ali Ibn Sino  980-1037            Buxoro Afshona  Hamadon
# 3  Abu Rayhon Beruniy  973-1048                Xorazm Kat   G'azna

# %%
df201 = pd.read_excel("201_DTM_Natijalari.xlsx", index_col = "№")
df201
# Out:
# C:\Users\QuadroMi\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                      ID raqam          Familiyasi va ismi  Majburiy-1  \
# №
# NaN                       NaN                         NaN   Ona tili
# 1                   201-guruh          Mahammadova Omatoy           9
# 2                   201-guruh         Tojiddinov  Shuhrat           5
# 3                   201-guruh        To'lanboyev Axrorbek           4
# 4                   201-guruh            Odilov Abdulaziz           6
# 5                   201-guruh             Bokirov Shoxrux           6
# 6                   201-guruh             Abiljonov Abbos           6
# 7                   201-guruh             Dehqonova Zuhra           2
# 8                   201-guruh      Ortiqpo'latov Muhiddin           6
# ...

# %%
df201
df201[df201['Familiyasi va ismi'] == df201.at[20, 2]]
# Out:
# Empty DataFrame
# Columns: [ID raqam, Familiyasi va ismi, Majburiy-1, Unnamed: 4, Majburiy-2, Unnamed: 6, Majburiy-3, Unnamed: 8, Asosiy 1-fan, Unnamed: 10, Asosiy 2-fan, Unnamed: 12, Umumiy ball]
# Index: []
